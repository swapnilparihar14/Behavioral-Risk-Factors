# %% [markdown]
# ## Project: Behavioral Risk Factors

# %% [markdown]
# #### Team Members
# Amit Sharma\
# Pranav Karmalkar\
# Swapnil Parihar

# %%
import pandas as pd
import numpy as np
import time
from sklearn import tree
from sklearn.model_selection import train_test_split
from xgboost import XGBClassifier
from matplotlib import pyplot
import re
from sklearn.ensemble import RandomForestClassifier
from sklearn import preprocessing

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data_2011 = pd.read_csv('2015.csv')

# %%
data_2011.describe()
# Out:
#               _STATE         FMONTH       DISPCODE         SEQNO  \
# count  441456.000000  441456.000000  441456.000000  4.414560e+05
# mean       29.968715       6.359676    1115.040457  2.015005e+09
# std        16.034710       3.487131      35.746794  4.113443e+03
# min         1.000000       1.000000    1100.000000  2.015000e+09
# 25%        19.000000       3.000000    1100.000000  2.015002e+09
# 50%        29.000000       6.000000    1100.000000  2.015004e+09
# 75%        44.000000       9.000000    1100.000000  2.015007e+09
# max        72.000000      12.000000    1200.000000  2.015023e+09
#
#                _PSU  CTELENUM       PVTRESD1  COLGHOUS  STATERES  \
# count  4.414560e+05  254645.0  254645.000000      45.0  254643.0
# mean   2.015005e+09       1.0       1.000177       1.0       1.0
# std    4.113443e+03       0.0       0.013292       0.0       0.0
# min    2.015000e+09       1.0       1.000000       1.0       1.0
# 25%    2.015002e+09       1.0       1.000000       1.0       1.0
# 50%    2.015004e+09       1.0       1.000000       1.0       1.0
# 75%    2.015007e+09       1.0       1.000000       1.0       1.0
# max    2.015023e+09       1.0       2.000000       1.0       1.0
#
#             CELLFON3  ...        _PAREC1       _PASTAE1       _LMTACT1  \
# count  254646.000000  ...  441456.000000  441456.000000  438657.000000
# mean        1.545133  ...       3.494124       2.742695       2.716879
# std         0.497960  ...       2.398322       2.449676       1.324145
# min         1.000000  ...       1.000000       1.000000       1.000000
# 25%         1.000000  ...       2.000000       2.000000       2.000000
# 50%         2.000000  ...       3.000000       2.000000       3.000000
# 75%         2.000000  ...       4.000000       2.000000       3.000000
# max         2.000000  ...       9.000000       9.000000       9.000000
#
#             _LMTWRK1       _LMTSCL1       _RFSEAT2       _RFSEAT3  \
# count  438657.000000  438657.000000  441456.000000  441456.000000
# mean        2.815149       3.652717       1.824624       1.887028
# std         1.356101       1.266730       2.360812       2.351387
# min         1.000000       1.000000       1.000000       1.000000
# 25%         2.000000       3.000000       1.000000       1.000000
# 50%         3.000000       4.000000       1.000000       1.000000
# 75%         3.000000       4.000000       1.000000       1.000000
# max         9.000000       9.000000       9.000000       9.000000
#
#             _FLSHOT6       _PNEUMO2       _AIDTST3
# count  157954.000000  157954.000000  398069.000000
# mean        2.290705       2.412259       1.970156
# std         2.518086       2.778032       1.441119
# min         1.000000       1.000000       1.000000
# 25%         1.000000       1.000000       1.000000
# 50%         1.000000       1.000000       2.000000
# 75%         2.000000       2.000000       2.000000
# max         9.000000       9.000000       9.000000
#
# [8 rows x 323 columns]

# %% [markdown]
# The Dataset for 2015 year has 323 columns

# %%
# Optional Step required only if target column contains Nan Values
data_2011.dropna(subset=['MENTHLTH'],inplace=True)

# %%
# See the names of the columns in the dataframe
L = sorted(data_2011.columns)

for i in L:
    print(i)
# Out:
# ACTIN11_
# ACTIN21_
# ADANXEV
# ADDEPEV2
# ADDOWN
# ADEAT1
# ADENERGY
# ADFAIL
# ADMOVE
# ADPLEASR
# ADSLEEP
# ADTHINK
# ALCDAY5
# ARTHDIS2
# ARTHEDU
# ARTHEXER
# ARTHSOCL
# ARTHWGT
# ARTTODAY
# ASACTLIM
# ASATTACK
# ASDRVIST
# ASERVIST
# ASINHALR
# ASNOSLEP
# ASPUNSAF
# ASRCHKUP
# ASTHMA3
# ASTHMAGE
# ASTHMED3
# ASTHNOW
# ASYMPTOM
# AVEDRNK2
# BEANDAY_
# BLDSTOOL
# BLDSUGAR
# BLIND
# BLOODCHO
# BPHIGH4
# BPMEDS
# CADULT
# CAREGIV1
# CASTHDX2
# CASTHNO2
# CCLGHOUS
# CDASSIST
# CDDISCUS
# CDHELP
# CDHOUSE
# CDSOCIAL
# CELLFON2
# CELLFON3
# CHCCOPD1
# CHCKIDNY
# CHCOCNCR
# CHCSCNCR
# CHECKUP1
# CHILDREN
# CHKHEMO3
# CHOLCHK
# CIMEMLOS
# COLGHOUS
# CPDEMO1
# CRGVEXPT
# CRGVHOUS
# CRGVHRS1
# CRGVLNG1
# CRGVMST2
# CRGVPERS
# CRGVPRB1
# CRGVREL1
# CSTATE
# CTELENUM
# CTELNUM1
# CVDASPRN
# CVDCRHD4
# CVDINFR4
# CVDSTRK3
# DECIDE
# DIABAGE2
# DIABEDU
# DIABETE3
# DIABEYE
# DIFFALON
# DIFFDRES
# DIFFWALK
# DISPCODE
# DOCTDIAB
# DRADVISE
# DRNK3GE5
# DRNKANY5
# DROCDY3_
# EDUCA
# EMPLOY1
# EMTSUPRT
# EXACTOT1
# EXACTOT2
# EXERANY2
# EXERHMM1
# EXERHMM2
# EXEROFT1
# EXEROFT2
# EXRACT11
# EXRACT21
# EYEEXAM
# FC60_
# FEETCHK
# FEETCHK2
# FLSHTMY2
# FLUSHOT6
# FMONTH
# FRUIT1
# FRUITJU1
# FRUTDA1_
# FTJUDA1_
# FVBEANS
# FVGREEN
# FVORANG
# GENHLTH
# GRENDAY_
# HADHYST2
# HADMAM
# HADPAP2
# HADSGCO1
# HADSIGM3
# HAREHAB1
# HAVARTH3
# HEIGHT3
# HHADULT
# HIVTST6
# HIVTSTD3
# HLTHPLN1
# HOWLONG
# HPLSTTST
# HPVADSHT
# HPVADVC2
# HPVTEST
# HTIN4
# HTM4
# IDATE
# IDAY
# IMFVPLAC
# IMONTH
# INCOME2
# INSULIN
# INTERNET
# IYEAR
# JOINPAIN
# LADULT
# LANDLINE
# LASTPAP2
# LASTSIG3
# LASTSMK2
# LENGEXAM
# LMTJOIN3
# LONGWTCH
# LSATISFY
# LSTBLDS3
# MARITAL
# MAXDRNKS
# MAXVO2_
# MEDCOST
# MENTHLTH
# METVL11_
# METVL21_
# MISTMNT
# MSCODE
# NUMADULT
# NUMHHOL2
# NUMMEN
# NUMPHON2
# NUMWOMEN
# ORNGDAY_
# PA1MIN_
# PA1VIGM_
# PADUR1_
# PADUR2_
# PAFREQ1_
# PAFREQ2_
# PAINACT2
# PAMIN11_
# PAMIN21_
# PAMISS1_
# PAVIG11_
# PAVIG21_
# PCDMDECN
# PCPSAAD2
# PCPSADE1
# PCPSADI1
# PCPSARE1
# PCPSARS1
# PDIABTST
# PERSDOC2
# PHYSHLTH
# PNEUVAC3
# POORHLTH
# PREDIAB1
# PREGNANT
# PROFEXAM
# PSATEST1
# PSATIME
# PVTRESD1
# PVTRESD2
# QLACTLM2
# QLHLTH2
# QLMENTL2
# QLSTRES2
# QSTLANG
# QSTVER
# RCSGENDR
# RCSRLTN2
# RDUCHART
# RDUCSTRK
# RENTHOM1
# RLIVPAIN
# SCNTLPAD
# SCNTLWK1
# SCNTMEL1
# SCNTMNY1
# SCNTPAID
# SCNTWRK1
# SEATBELT
# SEQNO
# SEX
# SHINGLE2
# SMOKDAY2
# SMOKE100
# STATERES
# STOPSMK2
# STREHAB1
# STRENGTH
# STRFREQ_
# SXORIENT
# TETANUS
# TOLDHI2
# TRNSGNDR
# USEEQUIP
# USENOW3
# VEGEDA1_
# VEGETAB1
# VETERAN3
# VICTRCT4
# VIDFCLT2
# VIEYEXM2
# VIGLUMA2
# VIINSUR2
# VIMACDG2
# VINOCRE2
# VIPRFVS2
# VIREDIF3
# WEIGHT2
# WHRTST10
# WTCHSALT
# WTKG3
# _AGE65YR
# _AGE80
# _AGEG5YR
# _AGE_G
# _AIDTST3
# _ASTHMS1
# _BMI5
# _BMI5CAT
# _CASTHM1
# _CHISPNC
# _CHLDCNT
# _CHOLCHK
# _CLLCPWT
# _CPRACE
# _CRACE1
# _DRDXAR1
# _DRNKWEK
# _DUALCOR
# _DUALUSE
# _EDUCAG
# _FLSHOT6
# _FRT16
# _FRTLT1
# _FRTRESP
# _FRUITEX
# _FRUTSUM
# _HCVU651
# _HISPANC
# _INCOMG
# _LLCPWT
# _LMTACT1
# _LMTSCL1
# _LMTWRK1
# _LTASTH1
# _MICHD
# _MINAC11
# _MINAC21
# _MISFRTN
# _MISVEGN
# _MRACE1
# _PA150R2
# _PA30021
# _PA300R2
# _PACAT1
# _PAINDX1
# _PAREC1
# _PASTAE1
# _PASTRNG
# _PNEUMO2
# _PRACE1
# _PSU
# _RACE
# _RACEG21
# _RACEGR3
# _RACE_G1
# _RAWRAKE
# _RFBING5
# _RFBMI5
# _RFCHOL
# _RFDRHV5
# _RFHLTH
# _RFHYPE5
# _RFSEAT2
# _RFSEAT3
# _RFSMOK3
# _SMOKER3
# _STATE
# _STRWT
# _STSTR
# _TOTINDA
# _VEG23
# _VEGESUM
# _VEGETEX
# _VEGLT1
# _VEGRESP
# _WT2RAKE

# %%
# Target Column variations available
data_2011['MENTHLTH'].value_counts()
# Out:
# 88.0    301076
# 30.0     22184
# 2.0      21229
# 5.0      14749
# 1.0      13658
# 3.0      12253
# 10.0     10684
# 15.0      9795
# 4.0       6259
# 20.0      5944
# 7.0       5667
# 77.0      5204
# 14.0      2229
# 99.0      2204
# 25.0      2081
# 6.0       1730
# 8.0       1140
# 12.0       706
# 28.0       591
# 21.0       404
# 29.0       333
# 9.0        203
# 18.0       178
# 16.0       174
# 27.0       154
# 22.0       116
# 17.0       101
# 13.0        93
# 26.0        76
# 11.0        73
# 23.0        70
# 24.0        67
# 19.0        31
# Name: MENTHLTH, dtype: int64

# %% [markdown]
# ### Dropping Derived Columns

# %%
# To identify and remove all derived columns that dilute the feature importance of original feature

L = []
for i in data_2011.columns:
    if i.startswith('_'):
        L.append(i)
data_2011.drop(L, axis=1, inplace = True)

# %%
test_set = data_2011.loc[data_2011.MENTHLTH.isin([77,99])]
test_set.head()
# Out:
#      FMONTH        IDATE IMONTH   IDAY    IYEAR  DISPCODE         SEQNO  \
# 24      1.0  b'01032015'  b'01'  b'03'  b'2015'    1100.0  2.015000e+09
# 40      1.0  b'01152015'  b'01'  b'15'  b'2015'    1100.0  2.015000e+09
# 55      2.0  b'02142015'  b'02'  b'14'  b'2015'    1100.0  2.015000e+09
# 93      3.0  b'03182015'  b'03'  b'18'  b'2015'    1100.0  2.015000e+09
# 130     1.0  b'01092015'  b'01'  b'09'  b'2015'    1100.0  2.015000e+09
#
#      CTELENUM  PVTRESD1  COLGHOUS  ...  PAFREQ1_  PAFREQ2_      STRFREQ_  \
# 24        1.0       1.0       NaN  ...    2000.0       NaN  5.397605e-79
# 40        1.0       1.0       NaN  ...    3000.0       NaN  5.397605e-79
# 55        1.0       1.0       NaN  ...       NaN       NaN  5.397605e-79
# 93        1.0       1.0       NaN  ...       NaN       NaN  5.397605e-79
# 130       1.0       1.0       NaN  ...       NaN       NaN  5.397605e-79
#
#          PAMISS1_  PAMIN11_      PAMIN21_  PA1MIN_      PAVIG11_  \
# 24   5.397605e-79      60.0  5.397605e-79     60.0  5.397605e-79
# 40   5.397605e-79     180.0  5.397605e-79    180.0  9.000000e+01
# 55   9.000000e+00       NaN           NaN      NaN           NaN
# 93   5.397605e-79       NaN           NaN      NaN           NaN
# 130  5.397605e-79       NaN           NaN      NaN           NaN
#
#          PAVIG21_      PA1VIGM_
# 24   5.397605e-79  5.397605e-79
# 40   5.397605e-79  9.000000e+01
# 55            NaN           NaN
# 93            NaN           NaN
# 130           NaN           NaN
#
# [5 rows x 254 columns]

# %% [markdown]
# Only 254 non-derived columns present. 69 columns were derived

# %% [markdown]
# ### Dropping Columns that do not have categorical values

# %%
# Remove columns of the type date

test_set = test_set.select_dtypes(exclude=['object'])
test_set.head()
# Out:
#      FMONTH  DISPCODE         SEQNO  CTELENUM  PVTRESD1  COLGHOUS  STATERES  \
# 24      1.0    1100.0  2.015000e+09       1.0       1.0       NaN       1.0
# 40      1.0    1100.0  2.015000e+09       1.0       1.0       NaN       1.0
# 55      2.0    1100.0  2.015000e+09       1.0       1.0       NaN       1.0
# 93      3.0    1100.0  2.015000e+09       1.0       1.0       NaN       1.0
# 130     1.0    1100.0  2.015000e+09       1.0       1.0       NaN       1.0
#
#      CELLFON3  LADULT  NUMADULT  ...  PAFREQ1_  PAFREQ2_      STRFREQ_  \
# 24        2.0     NaN       2.0  ...    2000.0       NaN  5.397605e-79
# 40        2.0     NaN       1.0  ...    3000.0       NaN  5.397605e-79
# 55        2.0     NaN       1.0  ...       NaN       NaN  5.397605e-79
# 93        2.0     NaN       2.0  ...       NaN       NaN  5.397605e-79
# 130       2.0     NaN       2.0  ...       NaN       NaN  5.397605e-79
#
#          PAMISS1_  PAMIN11_      PAMIN21_  PA1MIN_      PAVIG11_  \
# 24   5.397605e-79      60.0  5.397605e-79     60.0  5.397605e-79
# 40   5.397605e-79     180.0  5.397605e-79    180.0  9.000000e+01
# 55   9.000000e+00       NaN           NaN      NaN           NaN
# 93   5.397605e-79       NaN           NaN      NaN           NaN
# 130  5.397605e-79       NaN           NaN      NaN           NaN
#
#          PAVIG21_      PA1VIGM_
# 24   5.397605e-79  5.397605e-79
# 40   5.397605e-79  9.000000e+01
# 55            NaN           NaN
# 93            NaN           NaN
# 130           NaN           NaN
#
# [5 rows x 247 columns]

# %% [markdown]
#  8 non-categoical columns removed

# %% [markdown]
# ### Dropping columns with zero standard variation in the test set

# %%
# Removes all the columns with zero standard variation in the test set

test_set.drop(test_set.std()[(test_set.std() == 0)].index, axis=1,inplace = True)
test_set.head()
# Out:
#      FMONTH  DISPCODE         SEQNO  PVTRESD1  COLGHOUS  CELLFON3  LADULT  \
# 24      1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 40      1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 55      2.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 93      3.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 130     1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
#
#      NUMADULT        NUMMEN      NUMWOMEN  ...  PAFREQ1_  PAFREQ2_  \
# 24        2.0  1.000000e+00  1.000000e+00  ...    2000.0       NaN
# 40        1.0  1.000000e+00  5.397605e-79  ...    3000.0       NaN
# 55        1.0  5.397605e-79  1.000000e+00  ...       NaN       NaN
# 93        2.0  2.000000e+00  5.397605e-79  ...       NaN       NaN
# 130       2.0  1.000000e+00  1.000000e+00  ...       NaN       NaN
#
#          STRFREQ_      PAMISS1_  PAMIN11_      PAMIN21_  PA1MIN_  \
# 24   5.397605e-79  5.397605e-79      60.0  5.397605e-79     60.0
# 40   5.397605e-79  5.397605e-79     180.0  5.397605e-79    180.0
# 55   5.397605e-79  9.000000e+00       NaN           NaN      NaN
# 93   5.397605e-79  5.397605e-79       NaN           NaN      NaN
# 130  5.397605e-79  5.397605e-79       NaN           NaN      NaN
#
#          PAVIG11_      PAVIG21_      PA1VIGM_
# 24   5.397605e-79  5.397605e-79  5.397605e-79
# 40   9.000000e+01  5.397605e-79  9.000000e+01
# 55            NaN           NaN           NaN
# 93            NaN           NaN           NaN
# 130           NaN           NaN           NaN
#
# [5 rows x 242 columns]

# %% [markdown]
# 5 Columns having no variation in the test data removed

# %% [markdown]
# ### Dropping Columns that have too many NaN values (Optional)

# %%
# Removes all the columns with more than 95% values as Nan values

s = test_set.isnull().apply(sum, axis=0) # count the number of nan in each column
for col in test_set: 
    if s[col] >= 9200:  
        del test_set[col]
        
test_set.head()
# Out:
#      FMONTH  DISPCODE         SEQNO  PVTRESD1  COLGHOUS  CELLFON3  LADULT  \
# 24      1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 40      1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 55      2.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 93      3.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 130     1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
#
#      NUMADULT        NUMMEN      NUMWOMEN  ...  PAFREQ1_  PAFREQ2_  \
# 24        2.0  1.000000e+00  1.000000e+00  ...    2000.0       NaN
# 40        1.0  1.000000e+00  5.397605e-79  ...    3000.0       NaN
# 55        1.0  5.397605e-79  1.000000e+00  ...       NaN       NaN
# 93        2.0  2.000000e+00  5.397605e-79  ...       NaN       NaN
# 130       2.0  1.000000e+00  1.000000e+00  ...       NaN       NaN
#
#          STRFREQ_      PAMISS1_  PAMIN11_      PAMIN21_  PA1MIN_  \
# 24   5.397605e-79  5.397605e-79      60.0  5.397605e-79     60.0
# 40   5.397605e-79  5.397605e-79     180.0  5.397605e-79    180.0
# 55   5.397605e-79  9.000000e+00       NaN           NaN      NaN
# 93   5.397605e-79  5.397605e-79       NaN           NaN      NaN
# 130  5.397605e-79  5.397605e-79       NaN           NaN      NaN
#
#          PAVIG11_      PAVIG21_      PA1VIGM_
# 24   5.397605e-79  5.397605e-79  5.397605e-79
# 40   9.000000e+01  5.397605e-79  9.000000e+01
# 55            NaN           NaN           NaN
# 93            NaN           NaN           NaN
# 130           NaN           NaN           NaN
#
# [5 rows x 242 columns]

# %% [markdown]
# ### Manually dropping Columns that have an existing knowledge of The target Column

# %%
# Manually determined list of columns that have pre-existing knowledge of the target column
test_set.drop(columns = ['QLACTLM2','POORHLTH','DECIDE','DIFFALON'], axis=1, inplace = True)
test_set.head()
# Out:
#      FMONTH  DISPCODE         SEQNO  PVTRESD1  COLGHOUS  CELLFON3  LADULT  \
# 24      1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 40      1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 55      2.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 93      3.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
# 130     1.0    1100.0  2.015000e+09       1.0       NaN       2.0     NaN
#
#      NUMADULT        NUMMEN      NUMWOMEN  ...  PAFREQ1_  PAFREQ2_  \
# 24        2.0  1.000000e+00  1.000000e+00  ...    2000.0       NaN
# 40        1.0  1.000000e+00  5.397605e-79  ...    3000.0       NaN
# 55        1.0  5.397605e-79  1.000000e+00  ...       NaN       NaN
# 93        2.0  2.000000e+00  5.397605e-79  ...       NaN       NaN
# 130       2.0  1.000000e+00  1.000000e+00  ...       NaN       NaN
#
#          STRFREQ_      PAMISS1_  PAMIN11_      PAMIN21_  PA1MIN_  \
# 24   5.397605e-79  5.397605e-79      60.0  5.397605e-79     60.0
# 40   5.397605e-79  5.397605e-79     180.0  5.397605e-79    180.0
# 55   5.397605e-79  9.000000e+00       NaN           NaN      NaN
# 93   5.397605e-79  5.397605e-79       NaN           NaN      NaN
# 130  5.397605e-79  5.397605e-79       NaN           NaN      NaN
#
#          PAVIG11_      PAVIG21_      PA1VIGM_
# 24   5.397605e-79  5.397605e-79  5.397605e-79
# 40   9.000000e+01  5.397605e-79  9.000000e+01
# 55            NaN           NaN           NaN
# 93            NaN           NaN           NaN
# 130           NaN           NaN           NaN
#
# [5 rows x 238 columns]

# %% [markdown]
# 4 Columns identified and deleted in this process

# %% [markdown]
# Kindly note that while all the operations were performed on the test data they can be also applied to the training data. But we applied on the test for two reasons\
# 1) Test data is smaller so less computation is required for reading and manipulation the columns\
# 2) If a column has zero variance on test data, even if it has higher variation on the training data, it shows that the feature is not a good marker as for diffferenciating the probability of the disease

# %% [markdown]
# ### Training and target column pre-processing

# %%
training_set = data_2011.loc[~data_2011.MENTHLTH.isin([77,99])]

# %%
# Removes all the columns from the training set not in the training set

difference_list = list(set(training_set.columns) - set(test_set.columns))
training_set.drop(difference_list, axis=1, inplace = True)

# %%
# Define the target column
training_target = training_set[['MENTHLTH']]
test_target = test_set[['MENTHLTH']]

# %%
# Remove the target column before performing correlation
training_set.drop(columns=['MENTHLTH'],inplace=True)
test_set.drop(columns=['MENTHLTH'],inplace=True)

# %%
# Perform binary classification instead of multiclass classification for a simpler model with higher accuracy
training_target['MENTHLTH'].replace(88, 0, inplace=True)
for i in range(1,31):
    training_target['MENTHLTH'].replace(i, 1, inplace=True)

# %%
# Replace all the Nan values in the data training data 
training_set.fillna(99,inplace=True)

# %% [markdown]
# ### Dropping Columns that have high correlation (Optional)

# %%
corr_matrix = training_set.corr().abs()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

def plot_cov(data):
  # Covariance matrix for female
  cov_matrix = data.corr().abs()
  # Heatmap of above Covariance matrix
  f, ax = plt.subplots(figsize=(30, 24))
  sns.heatmap(cov_matrix, mask=np.zeros_like(cov_matrix, dtype=np.bool),
  cmap=sns.diverging_palette(220, 10, as_cmap=True), square=True, ax=ax)#, annot=True

# %%
plot_cov(training_set)

# %%
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.95
to_drop = [column for column in upper.columns if any(upper[column] > 0.98)]

# %%
len(to_drop)
# Out:
# 60

# %%
training_set.drop(to_drop, axis=1,inplace = True)

# %% [markdown]
# This shows that the data in most of the columns is highly correlated and so does not provide much unique information

# %% [markdown]
# ### Performing PCA for dimensionality reduction (Optional)

# %%
training_set= training_set.dropna(axis='columns')

# %%
# Scaling the data before performing PCA
ss_scaler = preprocessing.StandardScaler()
X_ss = ss_scaler.fit_transform(training_set)

# %%
X_ss_df = pd.DataFrame(data=X_ss[0:,0:],    # values
             #index=wine_df_mm[1:,0],    # 1st column as index
             columns=training_set.columns)

# %%
from sklearn.decomposition import PCA
pca = PCA(.99) #choose the minimum number of principal components such that 90% of the variance is retained
df_pca = pca.fit_transform(X_ss_df)

# %% [markdown]
# ## Overfitting random Forest Random forest model to ensure all relevant columns are extracted

# %%
model = RandomForestClassifier()
X_train, X_test, y_train, y_test = train_test_split(training_set, training_target,shuffle = True, test_size=0.2, random_state=42)
model.fit(training_set,training_target)
# Out:
# RandomForestClassifier()

# %%
import matplotlib.pyplot as plt
sorted_idx = model.feature_importances_.argsort()
plt.figure(figsize=(10,30))
plt.barh(training_set.columns[sorted_idx], model.feature_importances_[sorted_idx])
# Out:
# <BarContainer object of 177 artists>

# %%
from sklearn.metrics import classification_report
print("Detailed classification report:")
print()
y_true, y_pred = y_test, model.predict(X_test)
print(classification_report(y_true, y_pred))
print()
# Out:
# Detailed classification report:
#
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00     60394
#          1.0       1.00      1.00      1.00     26416
#
#     accuracy                           1.00     86810
#    macro avg       1.00      1.00      1.00     86810
# weighted avg       1.00      1.00      1.00     86810

# %%
model.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'auto',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# While the model clearly overfits the entire training data, this helps us extract only the most relevant features

# %% [markdown]
# ### Extracting the relevant columns and creating a new csv using limited to these columns

# %%
selected = training_set.columns[sorted_idx][-60:]

# %%
selected
# Out:
# Index(['DRNK3GE5', 'DIFFWALK', 'METVL11_', 'CHILDREN', 'METVL21_', 'CHECKUP1',
#        'CHOLCHK', 'IMFVPLAC', 'HHADULT', 'PA1VIGM_', 'MAXDRNKS', 'JOINPAIN',
#        'PAFREQ2_', 'EXRACT11', 'PADUR2_', 'EXEROFT2', 'EXERHMM2', 'STRENGTH',
#        'RENTHOM1', 'STRFREQ_', 'FLSHTMY2', 'EDUCA', 'PAMIN21_', 'HIVTSTD3',
#        'EXRACT21', 'PADUR1_', 'EXERHMM1', 'PAFREQ1_', 'DROCDY3_', 'EXEROFT1',
#        'ALCDAY5', 'MEDCOST', 'MARITAL', 'FRUITJU1', 'FTJUDA1_', 'PAMIN11_',
#        'PA1MIN_', 'FVORANG', 'ORNGDAY_', 'FVBEANS', 'FRUIT1', 'BEANDAY_',
#        'VEGETAB1', 'INCOME2', 'FRUTDA1_', 'VEGEDA1_', 'HTM4', 'FVGREEN',
#        'HTIN4', 'GRENDAY_', 'HEIGHT3', 'EMPLOY1', 'FMONTH', 'GENHLTH', 'WTKG3',
#        'WEIGHT2', 'SEQNO', 'MAXVO2_', 'PHYSHLTH', 'ADDEPEV2'],
#       dtype='object')

# %%
# Adding the target column to the above list
selected_2015 = ['DRNK3GE5', 'METVL11_', 'CHILDREN', 'IMFVPLAC', 'CHOLCHK', 'CHECKUP1',
       'METVL21_', 'MAXDRNKS', 'ARTHSOCL', 'PAFREQ2_', 'PA1VIGM_', 'EXRACT11',
       'PADUR2_', 'EXEROFT2', 'QSTVER', 'STRENGTH', 'RENTHOM1', 'STRFREQ_',
       'FLSHTMY2', 'EDUCA', 'EXERHMM2', 'HIVTSTD3', 'PAMIN21_', 'EXRACT21',
       'PADUR1_', 'EXERHMM1', 'PAFREQ1_', 'MEDCOST', 'DROCDY3_', 'ALCDAY5',
       'EXEROFT1', 'MARITAL', 'FTJUDA1_', 'FRUITJU1', 'PAMIN11_', 'ORNGDAY_',
       'FVORANG', 'PA1MIN_', 'FVBEANS', 'FRUIT1', 'BEANDAY_', 'INCOME2',
       'FRUTDA1_', 'VEGETAB1', 'VEGEDA1_', 'FVGREEN', 'GRENDAY_', 'EMPLOY1',
       'HTM4', 'HTIN4', 'HEIGHT3', 'FMONTH', 'WTKG3', 'WEIGHT2', 'GENHLTH',
       'SEQNO', 'MAXVO2_', 'FC60_', 'PHYSHLTH', 'ADDEPEV2','MENTHLTH']

# %%
data_2011.drop(data_2011.columns.difference(selected_2015), 1, inplace=True)

# %%
# Converting results to CSV 
compression_opts = dict(method='zip',archive_name='MENT2015R.csv')  
data_2011.to_csv('MENT2015R.zip', index=False,compression=compression_opts)
